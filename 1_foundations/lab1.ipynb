# %%
from dotenv import load_dotenv
load_dotenv(override=True)
import os
openai_api_key = os.getenv('OPENAI_API_KEY')

if openai_api_key:
    print(f"OpenAI API Key exists and begins {openai_api_key[:8]}")
else:
    print("OpenAI API Key not set - please head to the troubleshooting guide in the setup folder")
# Out:
# OpenAI API Key exists and begins sk-proj-

# %%
from openai import OpenAI  # pyright: ignore[reportMissingImports]
openai = OpenAI(api_key=openai_api_key)
messages = [{"role": "user", "content": "What is 12+2?"}]
result = openai.chat.completions.create(
    model="gpt-4.1-nano",
    messages=messages
)
print(result.choices[0].message.content)
# Out:
# 12 + 2 equals 14.

# %%
messages = [{"role": "user", "content": "Give me top 5 all time best movies"}]
result = openai.chat.completions.create(
    model="gpt-4.1-nano",
    messages=messages
)
print(result.choices[0].message.content)
# Out:
# Certainly! Choosing the top 5 all-time best movies can be subjective, but based on critical acclaim, cultural impact, and popularity, here are five films often considered among the greatest:
#
# 1. **The Shawshank Redemption (1994)** – Directed by Frank Darabont, this film tells a profound story of hope and friendship set in a prison, and has become a beloved classic.
# 2. **The Godfather (1972)** – Directed by Francis Ford Coppola, this epic tale of a New York crime family is frequently cited as one of the greatest films ever made.
# 3. **Citizen Kane (1941)** – Directed by Orson Welles, often regarded as a groundbreaking masterpiece in storytelling and cinematography.
# 4. **Pulp Fiction (1994)** – Quentin Tarantino's influential crime film known for its nonlinear narrative and sharp dialogue.
# 5. **Schindler's List (1993)** – Steven Spielberg's powerful portrayal of the Holocaust, acclaimed for its emotional depth and historical significance.
#
# Would you like recommendations based on specific genres or themes?
