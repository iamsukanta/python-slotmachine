# %%
from dotenv import load_dotenv
load_dotenv(override=True)
import os
openai_api_key = os.getenv("OPENAI_API_KEY")
if openai_api_key:
    print(f"OpenAI API Key exists and begins {openai_api_key[:8]}")
else:
    print("OpenAI API Key not set - please head to the troubleshooting guide in the setup folder")
# Out:
# OpenAI API Key exists and begins sk-proj-

# %%
from openai import OpenAI
openai_client = OpenAI(api_key=openai_api_key)
messages = [
    {"role": "system", "content": "You are a helpful assistant that can answer questions and help with tasks."},
    {"role": "user", "content": "Pick a business area that might be worth exploring for an Agentic AI opportunity"}
]
response = openai_client.chat.completions.create(
    model="gpt-4o-mini",
    messages=messages,
    max_tokens=100
)
business_area = response.choices[0].message.content

messages = [
    {"role": "system", "content": "You are a helpful assistant that will help with the following tasks."},
    {"role": "user", "content": f"Find pain-point in this business area: {business_area} - something challenging that might be ripe for an Agentic solution"}
]

response = openai_client.chat.completions.create(
    model="gpt-4o-mini",
    messages=messages,
    max_tokens=100
)
pain_point = response.choices[0].message.content

messages = [
    {"role": "system", "content": "You are a helpful assistant that will help with the following tasks."},
    {"role": "user", "content": f"Find a solution to this pain-point: {pain_point} - something that might be ripe for an Agentic solution"}
]

response = openai_client.chat.completions.create(
    model="gpt-4o-mini",
    messages=messages
)
solution = response.choices[0].message.content

print(solution)
# Out:
# ### Solution: Agentic AI for Data Integration and Interoperability in Personalized Healthcare
#
# #### Overview
# The integration and interoperability of healthcare data can be significantly improved through the use of Agentic AI, which refers to AI systems that can interact autonomously with various data sources, processes, and systems. This technology can address the fragmentation in healthcare data management, enabling a seamless flow of information across different providers and platforms.
#
# #### Key Components of the Solution
#
# 1. **AI-Powered Interoperability Framework**:
#    - Develop an AI framework that acts as a mediator between disparate EHR systems, lab results, and other healthcare databases. This framework would utilize standardized APIs and data protocols to automatically map and translate data fields between systems, ensuring that critical patient information is readily accessible regardless of the originating platform.
#
# 2. **Self-Learning Algorithms**:
# ...

# %%
from IPython.display import Markdown, display
display(Markdown(solution))
# Out:
# ### Solution: Agentic AI for Data Integration and Interoperability in Personalized Healthcare
#
# #### Overview
# The integration and interoperability of healthcare data can be significantly improved through the use of Agentic AI, which refers to AI systems that can interact autonomously with various data sources, processes, and systems. This technology can address the fragmentation in healthcare data management, enabling a seamless flow of information across different providers and platforms.
#
# #### Key Components of the Solution
#
# 1. **AI-Powered Interoperability Framework**:
#    - Develop an AI framework that acts as a mediator between disparate EHR systems, lab results, and other healthcare databases. This framework would utilize standardized APIs and data protocols to automatically map and translate data fields between systems, ensuring that critical patient information is readily accessible regardless of the originating platform.
#
# 2. **Self-Learning Algorithms**:
# ...
