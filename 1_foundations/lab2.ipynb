# %%
import os
import json
from dotenv import load_dotenv
from openai import OpenAI
from anthropic import Anthropic
from IPython.display import Markdown, display

# %%
load_dotenv(override=True)
openai_api_key = os.getenv("OPENAI_API_KEY")
gemini_api_key = os.getenv("GEMINI_API_KEY")

if openai_api_key:
    print(f"OpenAI API key found: {openai_api_key[:8]}")
else:
    print("OpenAI API key not found")

if gemini_api_key:
    print(f"Gemini API key found: {gemini_api_key[:8]}")
else:
    print("Gemini API key not found")
# Out:
# OpenAI API key found: sk-proj-
# Gemini API key found: AIzaSyC4

# %%
# openai call
openai_client = OpenAI(api_key=openai_api_key)
message = [{ 'role': 'user', 'content': 'When Berlin Wall was constructed, what was the consequence for the city of Berlin?'}];
response = openai_client.chat.completions.create(
    model="gpt-4o-mini",
    messages=message
)
print(response.choices[0].message.content)
# Out:
# The Berlin Wall was constructed in 1961 and did not replace a city; rather, it divided the city of Berlin into East and West. Before the wall was built, Berlin was a unified city, but it became divided during the Cold War, with East Berlin becoming the capital of East Germany (the German Democratic Republic) and West Berlin being a free city surrounded by East Germany. The wall was erected to prevent East Germans from fleeing to the West.

# %%
gemini_client = OpenAI(api_key=gemini_api_key, base_url="https://generativelanguage.googleapis.com/v1beta/openai")
message = [{ 'role': 'user', 'content': 'If I get into skilled employment visa not blue card how many months it will take to apply PR if I have B1 in Germay?'}]
response = gemini_client.chat.completions.create(
    model='gemini-2.5-flash',
    messages= message
)


response = response.choices[0].message.content

# %%
from IPython.display import Markdown, display
display(Markdown(response))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 2
#       1 from IPython.display import Markdown, display
# ----> 2 display(Markdown(response))
#
# File d:\my_projects\ai_agents\agents\.venv\Lib\site-packages\IPython\core\display.py:344, in DisplayObject.__init__(self, data, url, filename, metadata)
#     341     self.metadata = {}
#     343 self.reload()
# --> 344 self._check_data()
#
# File d:\my_projects\ai_agents\agents\.venv\Lib\site-packages\IPython\core\display.py:423, in TextDisplayObject._check_data(self)
#     421 def _check_data(self):
#     422     if self.data is not None and not isinstance(self.data, str):
# --> 423         raise TypeError("%s expects text, not %r" % (self.__class__.__name__, self.data))
#
# TypeError: Markdown expects text, not ChatCompletion(id='6o8sacitBbm0nsEP6PWdqA0', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content='If you are on a **skilled employment visa** in Germany that is **not a Blue Card** (this usually refers to a residence permit according to § 18a or § 18b of the Residence Act - AufenthG), and you have a **B1 German language level**, here\'s how long it typically takes to apply for Permanent Residence (Niederlassungserlaubnis):\n\nThe standard period for skilled workers on a non-Blue Card visa is **4 years (48 months)**.\n\nHere are the general requirements you would need to meet:\n\n1.  **Length of Stay:** You must have held your skilled employment residence permit for **at least 4 years (48 months)**.\n2.  **Pension Contributions:** You must have paid mandatory contributions to the statutory pension insurance scheme for **at least 48 months**. Periods of voluntary contributions or contributions to a professional pension scheme may count if equivalent.\n3.  **German Language Skills:** Your **B1 German level** is generally sufficient for this requirement. You\'ll need to provide proof (e.g., a certificate from an recognized language institute).\n4.  **Sufficient Income:** You must be able to support yourself and your family (if applicable) without relying on public funds. This means having a stable job with an adequate salary.\n5.  **Adequate Living Space:** You must have sufficient living space for yourself and your family.\n6.  **Knowledge of the Legal and Social Order:** You usually need to demonstrate knowledge of the legal and social order and living conditions in Germany. This is often fulfilled by completing an integration course (Integrationskurs) and passing the "Leben in Deutschland" (Living in Germany) test, or by demonstrating equivalent knowledge through education/work experience.\n7.  **No Criminal Record:** You must not have any significant criminal record.\n8.  **Valid Health Insurance:** You must have valid health insurance.\n\n**In summary:**\n\nWith your B1 German level and a skilled employment visa (non-Blue Card), you are looking at applying for Permanent Residence after **4 years (48 months)** of continuous skilled employment and contributions in Germany.\n\n**Important Considerations:**\n\n*   **Blue Card vs. Skilled Employment Visa:** It\'s worth reiterating that a Blue Card has a faster track: 33 months (with A1 German) or 21 months (with B1 German). Since you explicitly stated "not blue card," the 4-year rule applies.\n*   **Local Ausländerbehörde:** The exact documentation and processing times can vary slightly depending on the local Foreigners\' Office (Ausländerbehörde) responsible for your area. It\'s always a good idea to check their specific requirements and make an appointment well in advance.\n*   **Legal Changes:** German immigration law can change. Always verify the current requirements closer to your application date.', refusal=None, role='assistant', annotations=None, audio=None, function_call=None, tool_calls=None))], created=1764528106, model='gemini-2.5-flash', object='chat.completion', service_tier=None, system_fingerprint=None, usage=CompletionUsage(completion_tokens=605, prompt_tokens=29, total_tokens=1765, completion_tokens_details=None, prompt_tokens_details=None))
