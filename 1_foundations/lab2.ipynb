# %%
import os
import json
from dotenv import load_dotenv
from openai import OpenAI
from anthropic import Anthropic
from IPython.display import Markdown, display

# %%
load_dotenv(override=True)
openai_api_key = os.getenv("OPENAI_API_KEY")
gemini_api_key = os.getenv("GEMINI_API_KEY")

if openai_api_key:
    print(f"OpenAI API key found: {openai_api_key[:8]}")
else:
    print("OpenAI API key not found")

if gemini_api_key:
    print(f"Gemini API key found: {gemini_api_key[:8]}")
else:
    print("Gemini API key not found")
# Out:
# OpenAI API key found: sk-proj-
# Gemini API key found: AIzaSyC4

# %%
# openai call
openai_client = OpenAI(api_key=openai_api_key)
message = [{ 'role': 'user', 'content': 'When Berlin Wall was constructed, what was the consequence for the city of Berlin?'}];
response = openai_client.chat.completions.create(
    model="gpt-4o-mini",
    messages=message
)
print(response.choices[0].message.content)
# Out:
# The Berlin Wall was constructed in 1961 and did not replace a city; rather, it divided the city of Berlin into East and West. Before the wall was built, Berlin was a unified city, but it became divided during the Cold War, with East Berlin becoming the capital of East Germany (the German Democratic Republic) and West Berlin being a free city surrounded by East Germany. The wall was erected to prevent East Germans from fleeing to the West.

# %%
gemini_client = OpenAI(api_key=gemini_api_key, base_url="https://generativelanguage.googleapis.com/v1beta/openai")
message = [{ 'role': 'user', 'content': 'If I get into skilled employment visa not blue card how many months it will take to apply PR if I have B1 in Germay?'}]
response = gemini_client.chat.completions.create(
    model='gemini-2.5-flash',
    messages= message
)


response = response.choices[0].message.content

# %%
from IPython.display import Markdown, display
display(Markdown(response))
# Out:
# If you are on a **skilled employment visa** (likely under Section 18a or 18b of the Residence Act - AufenthG) and **not a Blue Card**, the standard waiting period before you can apply for **Permanent Residence (Niederlassungserlaubnis)** is **4 years**.
#
# Here's a breakdown of the key requirements you'll need to meet at the 4-year mark:
#
# 1.  **4 Years of Residence:** You must have resided in Germany for at least 4 years with a residence permit that allows gainful employment (your skilled employment visa counts).
# 2.  **48 Months of Pension Contributions:** You must have made at least 48 months of mandatory contributions to the German statutory pension scheme.
# 3.  **Secure Livelihood:** You must be able to support yourself and your family without relying on public funds (e.g., unemployment benefits, social welfare). Your current employment contract and salary slips will be assessed.
# ...
